# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
complaints_df = pd.read_csv('consumer-complaints.csv', index_col=0, encoding='ISO-8859–1')
complaints_df.head()
# Out:
#                                                          Product  \
# Date received
# 2021-03-23     Money transfer, virtual currency, or money ser...
# 2019-09-24                                       Debt collection
# 2019-09-19     Credit reporting, credit repair services, or o...
# 2019-11-08                                       Debt collection
# 2021-03-21     Money transfer, virtual currency, or money ser...
#
#                             Sub-product  \
# Date received
# 2021-03-23     Mobile or digital wallet
# 2019-09-24                I do not know
# 2019-09-19             Credit reporting
# 2019-11-08                I do not know
# 2021-03-21     Mobile or digital wallet
#
#                                                            Issue  \
# Date received
# 2021-03-23                                         Fraud or scam
# 2019-09-24                     Attempts to collect debt not owed
# 2019-09-19                  Incorrect information on your report
# ...

# %%
complaints_df.describe()
# Out:
#        Complaint ID
# count  2.033638e+06
# mean   2.590580e+06
# std    1.166640e+06
# min    1.000000e+00
# 25%    1.735942e+06
# 50%    2.872286e+06
# 75%    3.549778e+06
# max    4.273549e+06

# %%
sns.heatmap(complaints_df.corr(), annot=True)
plt.show()

# %%
zipcode_df = pd.read_csv('income-tax-zip-code.csv', index_col=0, encoding='ISO-8859–1')
zipcode_df.head()
# Out:
#           STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# STATEFIPS
# 1            AL        0         1  768120.0  466830.0   90960.0  198750.0
# 1            AL        0         2  503430.0  225110.0  130060.0  134320.0
# 1            AL        0         3  274590.0   95560.0  131770.0   41020.0
# 1            AL        0         4  174830.0   35560.0  123370.0   12700.0
# 1            AL        0         5  245150.0   25990.0  207950.0    6480.0
#
#                 ELF    CPREP      PREP  ...  N85300  A85300   N11901  \
# STATEFIPS                               ...
# 1          696930.0  37470.0  399160.0  ...     0.0     0.0  59030.0
# 1          457510.0  23180.0  266880.0  ...     0.0     0.0  77300.0
# 1          248630.0  13210.0  157800.0  ...     0.0     0.0  68920.0
# 1          159190.0   6830.0  102340.0  ...     0.0     0.0  47730.0
# 1          224280.0  10500.0  145010.0  ...    50.0    58.0  98980.0
#
# ...

# %%
zipcode_df.describe()
# Out:
#              zipcode       agi_stub            N1         mars1         MARS2  \
# count  165935.000000  165935.000000  1.659350e+05  1.659350e+05  1.659350e+05
# mean    48830.358665       3.499937  1.816297e+03  8.718270e+02  6.501056e+02
# std     27164.072793       1.707874  3.647389e+04  2.141347e+04  1.193886e+04
# min         0.000000       1.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     27010.000000       2.000000  7.000000e+01  0.000000e+00  4.000000e+01
# 50%     48821.000000       3.000000  2.600000e+02  7.000000e+01  1.100000e+02
# 75%     70634.000000       5.000000  1.050000e+03  3.600000e+02  3.800000e+02
# max     99999.000000       6.000000  5.493810e+06  3.974180e+06  1.796210e+06
#
#                MARS4           ELF          CPREP          PREP       DIR_DEP  \
# count  165935.000000  1.659350e+05  165935.000000  1.659350e+05  1.659350e+05
# mean      256.505439  1.635178e+03      99.639377  9.564313e+02  1.125977e+03
# ...

# %%
hate_crime_df = pd.read_csv('2019_HC_NATIONAL_MASTER_FILE_ENC_STATIC.txt', sep="\t")
hate_crime_df.head()
# Out:
#   BH50AK001010000000000000020200430       0Anchorage                     AK1C94 Y         3030020A         000287731  0 38000000000000000000  0   000000000000000000  0   000000000000000000  0   000000000000000000  0   0000000002019IIIZ    ANCHORAGE                      20
# 0  IR50AK0010100T33K8U7VSCTD20190926F300401W13B00...
# 1  IR50AK00101008X-VSBRU728N20190212F100101W13B00...
# 2  IR50AK00101007L-NTBYWPU7220190515F200101W13C00...
# 3  IR50AK0010100T338OIYVSCTD20190909F300102I12000...
# 4  IR50AK00101007L-TTGAWPU7220190720F300102I13A00...

# %%
shootings_df = pd.read_csv('NYPD_Shooting_Incident_Data__Historic_.csv', index_col = 0)
shootings_df.head()
# Out:
#               OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# INCIDENT_KEY
# 201575314     08/23/2019   22:10:00         QUEENS       103
# 205748546     11/27/2019   15:54:00          BRONX        40
# 193118596     02/02/2019   19:40:00      MANHATTAN        23
# 204192600     10/24/2019   00:52:00  STATEN ISLAND       121
# 201483468     08/22/2019   18:03:00          BRONX        46
#
#               JURISDICTION_CODE LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# INCIDENT_KEY
# 201575314                   0.0           NaN                    False
# 205748546                   0.0           NaN                    False
# 193118596                   0.0           NaN                    False
# 204192600                   0.0     PVT HOUSE                     True
# 201483468                   0.0           NaN                    False
#
#              PERP_AGE_GROUP PERP_SEX       PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# INCIDENT_KEY
# ...

# %%
shootings_df.describe()
# Out:
#            PRECINCT  JURISDICTION_CODE      Latitude     Longitude
# count  21626.000000       21624.000000  21626.000000  21626.000000
# mean      66.226857           0.326952     40.735844    -73.909345
# std       27.090769           0.738051      0.087330      0.066833
# min        1.000000           0.000000     40.511586    -74.249304
# 25%       44.000000           0.000000     40.667952    -73.943380
# 50%       69.000000           0.000000     40.697724    -73.915615
# 75%       81.000000           0.000000     40.823118    -73.882338
# max      123.000000           2.000000     40.910819    -73.702048

# %%
sns.heatmap(shootings_df.corr(), annot=True)
plt.show()

# %%
migrant_df = pd.read_csv('UN_International Migrants and Refugees.csv', index_col = 0)
migrant_df
# Out:
#                     International migrants and refugees Unnamed: 2  \
# T03
# Region/Country/Area                                 NaN       Year
# 1                         Total, all countries or areas       2005
# 1                         Total, all countries or areas       2005
# 1                         Total, all countries or areas       2005
# 1                         Total, all countries or areas       2005
# ...                                                 ...        ...
# 716                                            Zimbabwe       2019
# 716                                            Zimbabwe       2019
# 716                                            Zimbabwe       2019
# 716                                            Zimbabwe       2019
# 716                                            Zimbabwe       2019
#
#                                                             Unnamed: 3  \
# T03
# Region/Country/Area                                             Series
# ...

# %%
sns.heatmap(migrant_df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-021b1580aef8> in <module>
# ----> 1 sns.heatmap(migrant_df.corr(), annot=True)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
twitch1000_df = pd.read_csv('twitchdata-update.csv', index_col=0)
twitch1000_df
# Out:
#                   Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# Channel
# xQcOW                      6196161750                215250        222720
# summit1g                   6091677300                211845        310998
# Gaules                     5644590915                515280        387315
# ESL_CSGO                   3970318140                517740        300575
# Tfue                       3671000070                123660        285644
# ...                               ...                   ...           ...
# LITkillah                   122524635                 13560         21359
# 빅헤드 (bighead033)            122523705                153000          3940
# 마스카 (newmasca)              122452320                217410          6431
# AndyMilonakis               122311065                104745         10543
# Remx                        122192850                 99180         13788
#
# ...

# %%
twitch1000_df.describe()
# Out:
#        Watch time(Minutes)  Stream time(minutes)   Peak viewers  \
# count         1.000000e+03           1000.000000    1000.000000
# mean          4.184279e+08         120515.160000   37065.051000
# std           5.496355e+08          85376.201364   60314.307686
# min           1.221928e+08           3465.000000     496.000000
# 25%           1.631899e+08          73758.750000    9113.750000
# 50%           2.349908e+08         108240.000000   16676.000000
# 75%           4.337399e+08         141843.750000   37569.750000
# max           6.196162e+09         521445.000000  639375.000000
#
#        Average viewers     Followers  Followers gained  Views gained
# count      1000.000000  1.000000e+03      1.000000e+03  1.000000e+03
# mean       4781.040000  5.700541e+05      2.055185e+05  1.166817e+07
# std        8453.684965  8.044134e+05      3.399137e+05  2.490572e+07
# min         235.000000  3.660000e+03     -1.577200e+04  1.757880e+05
# ...

# %%
sns.heatmap(twitch1000_df.corr(), annot=True)
plt.show()

# %%
hate_df = pd.read_csv('hate_crime.csv', index_col = 0)
hate_df
# Out:
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              DATA_YEAR        ORI        PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# INCIDENT_ID
# 3015              1991  AR0040200                 Rogers             NaN
# 3016              1991  AR0290100                   Hope             NaN
# 43                1991  AR0350100             Pine Bluff             NaN
# 44                1991  AR0350100             Pine Bluff             NaN
# 3017              1991  AR0350100             Pine Bluff             NaN
# ...                ...        ...                    ...             ...
# 558879            2019  WY0010100                Laramie             NaN
# 558880            2019  WY0010200  University of Wyoming             NaN
# ...

# %%
sns.heatmap(hate_df.corr(), annot=True)
plt.show()

# %%
hate_df.dtypes
# Out:
# DATA_YEAR                     int64
# ORI                          object
# PUB_AGENCY_NAME              object
# PUB_AGENCY_UNIT              object
# AGENCY_TYPE_NAME             object
# STATE_ABBR                   object
# STATE_NAME                   object
# DIVISION_NAME                object
# REGION_NAME                  object
# POPULATION_GROUP_CODE        object
# POPULATION_GROUP_DESC        object
# INCIDENT_DATE                object
# ADULT_VICTIM_COUNT          float64
# JUVENILE_VICTIM_COUNT       float64
# TOTAL_OFFENDER_COUNT          int64
# ADULT_OFFENDER_COUNT        float64
# JUVENILE_OFFENDER_COUNT     float64
# OFFENDER_RACE                object
# OFFENDER_ETHNICITY           object
# VICTIM_COUNT                  int64
# OFFENSE_NAME                 object
# TOTAL_INDIVIDUAL_VICTIMS    float64
# LOCATION_NAME                object
# BIAS_DESC                    object
# VICTIM_TYPES                 object
# MULTIPLE_OFFENSE             object
# ...

# %%
hate_df['LOCATION_NAME'].value_counts()
# Out:
# Residence/Home                                                       62084
# Highway/Road/Alley/Street/Sidewalk                                   39566
# Other/Unknown                                                        28357
# School/College                                                       17440
# Parking/Drop Lot/Garage                                              11879
#                                                                      ...
# Air/Bus/Train Terminal;Highway/Road/Alley/Street/Sidewalk                1
# Commercial/Office Building;Field/Woods                                   1
# Church/Synagogue/Temple/Mosque;Highway/Road/Alley/Street/Sidewalk        1
# Department/Discount Store;Other/Unknown                                  1
# Commercial/Office Building;Department/Discount Store                     1
# Name: LOCATION_NAME, Length: 123, dtype: int64

# %%
hate_df['OFFENDER_RACE'].value_counts()
# Out:
# Unknown                                      92640
# White                                        82629
# Black or African American                    27191
# Multiple                                      4238
# Asian                                         1514
# American Indian or Alaska Native              1154
# Native Hawaiian or Other Pacific Islander       56
# Name: OFFENDER_RACE, dtype: int64

# %%
hate_df['BIAS_DESC'].value_counts()
# Out:
# Anti-Black or African American                                                                   71227
# Anti-Jewish                                                                                      27153
# Anti-White                                                                                       24063
# Anti-Gay (Male)                                                                                  21097
# Anti-Hispanic or Latino                                                                          13400
#                                                                                                  ...
# Anti-Other Race/Ethnicity/Ancestry;Anti-Sikh                                                         1
# Anti-Islamic (Muslim);Anti-Other Religion                                                            1
# Anti-Arab;Anti-Hispanic or Latino;Anti-Other Race/Ethnicity/Ancestry                                 1
# ...

# %%
hate_df['OFFENSE_NAME'].value_counts()
# Out:
# Destruction/Damage/Vandalism of Property                                                           64262
# Intimidation                                                                                       60971
# Simple Assault                                                                                     39768
# Aggravated Assault                                                                                 21843
# Robbery                                                                                             3573
#                                                                                                    ...
# Burglary/Breaking & Entering;Motor Vehicle Theft;Not Specified                                         1
# Aggravated Assault;Destruction/Damage/Vandalism of Property;Intimidation;Robbery;Simple Assault        1
# All Other Larceny;Destruction/Damage/Vandalism of Property;Theft From Motor Vehicle                    1
# ...

# %%
hate_df['DATA_YEAR'].value_counts()
# Out:
# 2001    9730
# 1996    8790
# 2000    8219
# 1997    8107
# 2008    8039
# 2019    8028
# 1995    7950
# 1999    7944
# 1998    7902
# 2006    7716
# 2004    7685
# 2007    7625
# 1993    7608
# 2003    7545
# 2002    7485
# 2005    7411
# 2017    7325
# 2018    7190
# 1992    6667
# 2010    6631
# 2009    6613
# 2012    6594
# 2011    6300
# 2016    6273
# 2013    6044
# 1994    5954
# 2015    5879
# 2014    5599
# 1991    4589
# Name: DATA_YEAR, dtype: int64
