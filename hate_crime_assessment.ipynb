# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('hate_crime.csv', index_col = 0)
df
# Out:
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              DATA_YEAR        ORI        PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# INCIDENT_ID
# 3015              1991  AR0040200                 Rogers             NaN
# 3016              1991  AR0290100                   Hope             NaN
# 43                1991  AR0350100             Pine Bluff             NaN
# 44                1991  AR0350100             Pine Bluff             NaN
# 3017              1991  AR0350100             Pine Bluff             NaN
# ...                ...        ...                    ...             ...
# 558879            2019  WY0010100                Laramie             NaN
# 558880            2019  WY0010200  University of Wyoming             NaN
# ...

# %%
hate_df.dtypes
# Out:
# DATA_YEAR                     int64
# ORI                          object
# PUB_AGENCY_NAME              object
# PUB_AGENCY_UNIT              object
# AGENCY_TYPE_NAME             object
# STATE_ABBR                   object
# STATE_NAME                   object
# DIVISION_NAME                object
# REGION_NAME                  object
# POPULATION_GROUP_CODE        object
# POPULATION_GROUP_DESC        object
# INCIDENT_DATE                object
# ADULT_VICTIM_COUNT          float64
# JUVENILE_VICTIM_COUNT       float64
# TOTAL_OFFENDER_COUNT          int64
# ADULT_OFFENDER_COUNT        float64
# JUVENILE_OFFENDER_COUNT     float64
# OFFENDER_RACE                object
# OFFENDER_ETHNICITY           object
# VICTIM_COUNT                  int64
# OFFENSE_NAME                 object
# TOTAL_INDIVIDUAL_VICTIMS    float64
# LOCATION_NAME                object
# BIAS_DESC                    object
# VICTIM_TYPES                 object
# MULTIPLE_OFFENSE             object
# ...

# %%
ca_df = df[df["STATE_NAME"] == "California"]
ca_df
# Out:
#              DATA_YEAR        ORI                  PUB_AGENCY_NAME  \
# INCIDENT_ID
# 48                1991  CA0300900                     Garden Grove
# 49                1991  CA0300900                     Garden Grove
# 50                1991  CA0300900                     Garden Grove
# 51                1991  CA0300900                     Garden Grove
# 52                1991  CA0300900                     Garden Grove
# ...                ...        ...                              ...
# 692896            2019  CAFBILA00  Federal Bureau of Investigation
# 723326            2019  CAFBILA00  Federal Bureau of Investigation
# 692931            2019  CAFBISC00  Federal Bureau of Investigation
# 692932            2019  CAFBISC00  Federal Bureau of Investigation
# 692933            2019  CAFBISC00  Federal Bureau of Investigation
#
#             PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR  STATE_NAME  \
# INCIDENT_ID
# ...

# %%
ca_df['BIAS_DESC'].value_counts()
# Out:
# Anti-Black or African American                                                              10852
# Anti-Gay (Male)                                                                              5041
# Anti-Jewish                                                                                  3759
# Anti-Hispanic or Latino                                                                      3235
# Anti-Other Race/Ethnicity/Ancestry                                                           2327
# Anti-White                                                                                   2197
# Anti-Asian                                                                                   1702
# Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)                                    1388
# Anti-Multiple Races, Group                                                                   1208
# Anti-Lesbian (Female)                                                                         909
# ...

# %%
asian_hate = ca_df[ca_df["BIAS_DESC"] == "Anti-Asian"]
asian_hate
# Out:
#              DATA_YEAR        ORI               PUB_AGENCY_NAME  \
# INCIDENT_ID
# 51                1991  CA0300900                  Garden Grove
# 4727              1992  CA0300900                  Garden Grove
# 4730              1992  CA0300900                  Garden Grove
# 4736              1992  CA0380100                 San Francisco
# 4746              1992  CA0380100                 San Francisco
# ...                ...        ...                           ...
# 688364            2019  CA0431300                      San Jose
# 551774            2019  CA043950X  Santa Clara Transit District
# 551906            2019  CA0520200                     Red Bluff
# 647193            2019  CA0579700     University of California:
# 647194            2019  CA0579700     University of California:
#
#             PUB_AGENCY_UNIT       AGENCY_TYPE_NAME STATE_ABBR  STATE_NAME  \
# INCIDENT_ID
# 51                      NaN                   City         CA  California
# ...

# %%
asian_hate['OFFENSE_NAME'].value_counts()
# Out:
# Destruction/Damage/Vandalism of Property                                                   545
# Intimidation                                                                               480
# Simple Assault                                                                             323
# Aggravated Assault                                                                         189
# Robbery                                                                                     29
# Intimidation;Simple Assault                                                                 24
# Destruction/Damage/Vandalism of Property;Intimidation                                       17
# Burglary/Breaking & Entering                                                                14
# Aggravated Assault;Intimidation                                                             11
# Burglary/Breaking & Entering;Destruction/Damage/Vandalism of Property                       10
# ...

# %%
asian_hate['OFFENDER_RACE'].value_counts()
# Out:
# Unknown                                      760
# White                                        678
# Black or African American                    180
# Multiple                                      44
# Asian                                         33
# American Indian or Alaska Native               6
# Native Hawaiian or Other Pacific Islander      1
# Name: OFFENDER_RACE, dtype: int64

# %%
asian_hate['LOCATION_NAME'].value_counts()
# Out:
# Residence/Home                                   573
# Highway/Road/Alley/Street/Sidewalk               402
# Parking/Drop Lot/Garage                          109
# School/College                                    90
# Restaurant                                        72
# Commercial/Office Building                        61
# Specialty Store                                   50
# Air/Bus/Train Terminal                            44
# Other/Unknown                                     35
# Field/Woods                                       28
# Church/Synagogue/Temple/Mosque                    27
# Grocery/Supermarket                               27
# Jail/Prison/Penitentiary/Corrections Facility     26
# Convenience Store                                 23
# Service/Gas Station                               15
# Drug Store/Doctor's Office/Hospital               14
# Liquor Store                                      13
# Department/Discount Store                         12
# ...

# %%
asian_hate['DATA_YEAR'].value_counts()
# Top 5 years where the most reports of Anti-Asian hate crimes in CA were 1997, 1996, 1995, 1998, & 1999
# 2019 was 14th
# Out:
# 1997    160
# 1996    152
# 1995    142
# 1998    135
# 1999    126
# 2000    100
# 2001     93
# 2002     70
# 2004     69
# 2003     66
# 2007     54
# 2006     52
# 2005     50
# 2019     43
# 2008     37
# 2017     37
# 1993     36
# 2018     34
# 1994     33
# 2010     32
# 2011     30
# 2013     30
# 2009     25
# 2012     24
# 2016     22
# 2014     19
# 2015     19
# 1992     11
# 1991      1
# Name: DATA_YEAR, dtype: int64

# %%
sns.heatmap(asian_hate.corr(), annot=True)
plt.show()

# %%
asian_hate.hist()
# Out:
# array([[<AxesSubplot:title={'center':'DATA_YEAR'}>,
#         <AxesSubplot:title={'center':'ADULT_VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_VICTIM_COUNT'}>],
#        [<AxesSubplot:title={'center':'TOTAL_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'ADULT_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_OFFENDER_COUNT'}>],
#        [<AxesSubplot:title={'center':'VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'TOTAL_INDIVIDUAL_VICTIMS'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
ca_asian_hate = df[(df["STATE_NAME"] == "California") & (df["BIAS_DESC"] == "Anti-Asian")]
ca_asian_hate.hist()
# Out:
# array([[<AxesSubplot:title={'center':'DATA_YEAR'}>,
#         <AxesSubplot:title={'center':'ADULT_VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_VICTIM_COUNT'}>],
#        [<AxesSubplot:title={'center':'TOTAL_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'ADULT_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_OFFENDER_COUNT'}>],
#        [<AxesSubplot:title={'center':'VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'TOTAL_INDIVIDUAL_VICTIMS'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
asian_hate = df[(df["BIAS_DESC"] == "Anti-Asian")]
asian_hate.hist()
# Out:
# array([[<AxesSubplot:title={'center':'DATA_YEAR'}>,
#         <AxesSubplot:title={'center':'ADULT_VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_VICTIM_COUNT'}>],
#        [<AxesSubplot:title={'center':'TOTAL_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'ADULT_OFFENDER_COUNT'}>,
#         <AxesSubplot:title={'center':'JUVENILE_OFFENDER_COUNT'}>],
#        [<AxesSubplot:title={'center':'VICTIM_COUNT'}>,
#         <AxesSubplot:title={'center':'TOTAL_INDIVIDUAL_VICTIMS'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_axis = ["Children", "Women", "Men"]
data = [child_chance_of_survival, women_chance_of_survival, men_chance_of_survival]
ax.bar(x_axis, data)
plt.show()
